# %% [markdown]
# <a href="https://colab.research.google.com/github/pgomesbueno/bigdata_docker/blob/master/Estudo_de_caso_salario_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url_arquivo_csv = 'https://drive.google.com/uc?id=1rEkB5GBUuYJT6fHXA1vYagnLnbPmc3a0'

# %%
#Leitura dos dados
dados = pd.read_csv(url_arquivo_csv)

# %%
dados.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
dados['YearsExperience'].mean()
# Out:
# 5.3133333333333335

# %%
dados['Salary'].hist()
# Out:
# <Axes: >

# %%
dados['Salary'].mean()
# Out:
# 76003.0

# %%
dados['Salary'].std()
# Out:
# 27414.4297845823

# %%
dados.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
plt.scatter(dados['YearsExperience'], dados['Salary'])
plt.xlabel('Anos de Experiência')
plt.ylabel('Salário')
# Out:
# Text(0, 0.5, 'Salário')

# %%
#Covariância
dados.cov()
# Out:
#                  YearsExperience        Salary
# YearsExperience         8.053609  7.610630e+04
# Salary              76106.303448  7.515510e+08

# %%
#correlação
dados.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
pip install statsmodels

# %%
import statsmodels.api as sm

# %%
modelo = sm.OLS(dados['Salary'],dados['YearsExperience']).fit()

# %%
print(modelo.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.973
# Model:                            OLS   Adj. R-squared (uncentered):              0.972
# Method:                 Least Squares   F-statistic:                              1048.
# Date:                Sat, 16 Mar 2024   Prob (F-statistic):                    2.56e-24
# Time:                        16:37:25   Log-Likelihood:                         -327.28
# No. Observations:                  30   AIC:                                      656.6
# Df Residuals:                      29   BIC:                                      658.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...
